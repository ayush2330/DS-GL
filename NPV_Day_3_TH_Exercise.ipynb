# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Take - home
#                         <br> (Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Let's begin with some hands-on practice exercises.
#
# **Create a dataframe wherever necessary**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Compute minimum and maximum sales for each store and location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# write your code here
df=pd.read_csv('city.csv')
df.pivot_table(index=['Store','Location'],values='Sales',aggfunc=['min','max'],margins=True)
# Out:
#                    min    max
#                  Sales  Sales
# Store Location
# A     Delhi      87000  87000
#       Hyderabad  50000  50000
#       Mumbai     40000  40000
#       Pune       78000  78000
# B     Pune       45000  70000
# C     Mumbai     89000  90000
# D     Hyderabad  85000  85000
#       Pune       89000  89000
# All              40000  90000

# %%
df.pivot_table(index=['Store','Location'],values='Sales',aggfunc=['min','max'],margins=True)
# Out:
#                    min    max
#                  Sales  Sales
# Store Location
# A     Delhi      87000  87000
#       Hyderabad  50000  50000
#       Mumbai     40000  40000
#       Pune       78000  78000
# B     Pune       45000  70000
# C     Mumbai     89000  90000
# D     Hyderabad  85000  85000
#       Pune       89000  89000
# All              40000  90000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Find duplicate rows based on the column 'Name'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachin</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
# Write your code here
df1=pd.read_excel('Book2.xlsx')
df1[df1.duplicated(subset=['Name'])]
# Out:
#      Name  Salary     City
# 3  Robert    3000  Chicago
# 4  Robert    3000  Chicago
# 5  Robert    3000    Texas
# 6    Aadi    4000   London

# %%
df1[df1.duplicated(subset=['Name'])]
# Out:
#      Name  Salary     City
# 3  Robert    3000  Chicago
# 4  Robert    3000  Chicago
# 5  Robert    3000    Texas
# 6    Aadi    4000   London

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3.  In column tournament, replace all the 'football' values  with 'cricket' using numpy.where
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
# Write your code here
df2=pd.read_excel('Book3.xlsx')
np.where(df2['Tournament']=='Football','Cricket',df2['Tournament'])
# Out:
# array(['Cricket', 'Cricket', 'Cricket', 'Cricket', 'Cricket'],
#       dtype=object)

# %%
np.where(df2['Tournament']=='Football','Cricket',df2['Tournament'])
# Out:
# array(['Cricket', 'Cricket', 'Cricket', 'Cricket', 'Cricket'],
#       dtype=object)

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Get the descriptive statistics of the sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
month=['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec']
sales=[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000]
seasons=['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']
df3=pd.DataFrame({'Month':month,'Sales':sales,'Seasons':seasons})
df3.describe().T
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
month=['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec']
sales=[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000]
seasons=['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']
d3=pd.DataFrame({'Month':month,'Sales':sales,'Seasons':seasons})
d3.describe().T
# Out:
#        count          mean        std      min      25%      50%      75%  \
# Sales   12.0  48166.666667  19385.249  22000.0  28500.0  56000.0  61750.0
#
#            max
# Sales  78000.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Create a new column age with values of your choice. And append it to the below dataframe.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
# Write your code here
name=['Emma','Mia','Sophia','James','John']
maths=[56,78,78,67,88]
sc=[89,87,78,89,78]
eng=[89,89,76,78,87]
df4=pd.DataFrame({'Name':name,'Maths':maths,'Science':sc,'English':eng})
df4['Age']=[23,24,25,26,27]
df4
# Out:
#      Name  Maths  Science  English  Age
# 0    Emma     56       89       89   23
# 1     Mia     78       87       89   24
# 2  Sophia     78       78       76   25
# 3   James     67       89       78   26
# 4    John     88       78       87   27

# %%
name=['Emma','Mia','Sophia','James','John']
maths=[56,78,78,67,88]
sc=[89,87,78,89,78]
eng=[89,89,76,78,87]
df4=pd.DataFrame({'Name':name,'Maths':maths,'Science':sc,'English':eng})
df4['Age']=[23,24,25,26,27]
df4
# Out:
#      Name  Maths  Science  English  Age
# 0    Emma     56       89       89   23
# 1     Mia     78       87       89   24
# 2  Sophia     78       78       76   25
# 3   James     67       89       78   26
# 4    John     88       78       87   27

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Perform right join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#         <td>Geography</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#         <td>History</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
# Write your code here
df4=pd.read_excel('que6.xlsx',sheet_name=0)
df5=pd.read_excel('que6.xlsx',sheet_name=1)
df4.join(df5,lsuffix='L',rsuffix='R',how='right')
# Out:
#    Stud_IDL   Name  MA(Hons)L  Stud_IDR   Res_City  MA(Hons)R
# 0       101   Alex    History       101      Delhi    English
# 1       102    Amy    English       102     Mumbai    History
# 2       103  Allen  Geography       103      Delhi  Fine Arts
# 3       104  Alice     German       104    Chennai     German
# 4       105  James    History       105  Hyderabad    History

# %%
df4=pd.read_excel('que6.xlsx',sheet_name=0)
df5=pd.read_excel('que6.xlsx',sheet_name=1)
df4.join(df5,lsuffix='L',rsuffix='R',how='right')
# Out:
#    Stud_IDL   Name  MA(Hons)L  Stud_IDR   Res_City  MA(Hons)R
# 0       101   Alex    History       101      Delhi    English
# 1       102    Amy    English       102     Mumbai    History
# 2       103  Allen  Geography       103      Delhi  Fine Arts
# 3       104  Alice     German       104    Chennai     German
# 4       105  James    History       105  Hyderabad    History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Using the dataframes created in question 6, perform inner join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Write your code here
#df4.join(df5,on=['MA(Hons)','Stud_ID'])
df4.set_index(['MA(Hons)','Stud_ID']).join(df5.set_index(['MA(Hons)','Stud_ID']),how='inner')
# Out:
#                    Name   Res_City
# MA(Hons) Stud_ID
# German   104      Alice    Chennai
# History  105      James  Hyderabad

# %%
df4.set_index(['MA(Hons)','Stud_ID']).join(df5.set_index(['MA(Hons)','Stud_ID']),how='inner')
# Out:
#                    Name   Res_City
# MA(Hons) Stud_ID
# German   104      Alice    Chennai
# History  105      James  Hyderabad

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Concatenate two dataframes along the columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
# Write your code here
df6=pd.read_excel('que8.xlsx',sheet_name=0)
df7=pd.read_excel('que8.xlsx',sheet_name=1)
pd.concat([df6,df7],axis=0)
# Out:
#    Stud_ID   Name   Res_City   MA(Hons)
# 0    101.0   Alex        NaN        NaN
# 1    102.0    Amy        NaN        NaN
# 2    103.0  Allen        NaN        NaN
# 3    104.0  Alice        NaN        NaN
# 4    105.0  James        NaN        NaN
# 0      NaN    NaN      Delhi    English
# 1      NaN    NaN     Mumbai    History
# 2      NaN    NaN      Delhi  Fine Arts
# 3      NaN    NaN    Chennai     German
# 4      NaN    NaN  Hyderabad    History

# %%
df6=pd.read_excel('que8.xlsx',sheet_name=0)
df7=pd.read_excel('que8.xlsx',sheet_name=1)
pd.concat([df6,df7],axis=0)
# Out:
#    Stud_ID   Name   Res_City   MA(Hons)
# 0    101.0   Alex        NaN        NaN
# 1    102.0    Amy        NaN        NaN
# 2    103.0  Allen        NaN        NaN
# 3    104.0  Alice        NaN        NaN
# 4    105.0  James        NaN        NaN
# 0      NaN    NaN      Delhi    English
# 1      NaN    NaN     Mumbai    History
# 2      NaN    NaN      Delhi  Fine Arts
# 3      NaN    NaN    Chennai     German
# 4      NaN    NaN  Hyderabad    History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9. Calculate minimum, maximum and average sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
# Write your code here
df3
df3.pivot_table(index=['Seasons'],values='Sales',aggfunc=['min','max','mean'],margins=True)
# Out:
#            min    max          mean
#          Sales  Sales         Sales
# Seasons
# Fall     56000  56000  56000.000000
# Spring   25000  35000  29666.666667
# Summer   67000  78000  70666.666667
# Winter   22000  60000  36333.333333
# All      22000  78000  48166.666667

# %%
df3.pivot_table(index=['Seasons'],values='Sales',aggfunc=['min','max','mean'],margins=True)
# Out:
#            min    max          mean
#          Sales  Sales         Sales
# Seasons
# Fall     56000  56000  56000.000000
# Spring   25000  35000  29666.666667
# Summer   67000  78000  70666.666667
# Winter   22000  60000  36333.333333
# All      22000  78000  48166.666667

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10. Find all the duplicate entries based on the columns X and Y.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>X</th>
# <th>Y</th>
# <th>Z</th>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>5</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1</td>
# <td>2</td>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>1</td>
# </tr>
# <tr>
# <td>3</td>
# <td>4</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>2</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>8</td>
# </tr>
#
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
# Write your code here
x=[1,2,3,1,2,3,2,2]
y=[2,2,1,2,2,4,2,2]
z=[5,6,2,6,1,6,2,8]
df8=pd.DataFrame({'X':x,'Y':y,'Z':z})
df8[df8.duplicated(subset=['X','Y'])]
# Out:
#    X  Y  Z
# 3  1  2  6
# 4  2  2  1
# 6  2  2  2
# 7  2  2  8

# %%
x=[1,2,3,1,2,3,2,2]
y=[2,2,1,2,2,4,2,2]
z=[5,6,2,6,1,6,2,8]
df=pd.DataFrame({'X':x,'Y':y,'Z':z})
df[df.duplicated(subset=['X','Y'])]
# Out:
#    X  Y  Z
# 3  1  2  6
# 4  2  2  1
# 6  2  2  2
# 7  2  2  8
