# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
# type your code here
df_adult=pd.read_csv('adult.csv')
df_adult.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(x=df_adult['age'],y=df_adult['hours.per.week'])
# Out:
# <Axes: xlabel='age', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_adult[['capital.gain','education.num']].groupby('education.num').mean().plot(figsize=(15,8))
# Out:
# <Axes: xlabel='education.num'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(x=df_adult['hours.per.week'],y=df_adult['capital.gain'])
# Out:
# <Axes: xlabel='hours.per.week', ylabel='capital.gain'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_adult[['age','hours.per.week']].groupby('age').mean().plot(figsize=(15,8))
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_adult[['age','capital.loss']].groupby('age').mean().plot(figsize=(15,8))
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(x=df_adult['capital.gain'],y=df_adult['age'])
# Out:
# <Axes: xlabel='capital.gain', ylabel='age'>

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.barplot(x='income',y='age',data=df_adult)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.violinplot(x='sex',y='hours.per.week',data=df_adult)
# Out:
# <Axes: xlabel='sex', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.boxplot(x='income',y='education.num',data=df_adult)
# Out:
# <Axes: xlabel='income', ylabel='education.num'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.barplot(x='sex',y='age',data=df_adult)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.boxplot(x='income',y='hours.per.week',data=df_adult)
# Out:
# <Axes: xlabel='income', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.violinplot(x='race',y='age',data=df_adult,hue='sex',split='sex')
# Out:
# <Axes: xlabel='race', ylabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.boxplot(x='workclass',y='hours.per.week',data=df_adult)
# Out:
# <Axes: xlabel='workclass', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.boxplot(x='sex',y='fnlwgt',data=df_adult)
# Out:
# <Axes: xlabel='sex', ylabel='fnlwgt'>

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
it=pd.crosstab(index=df_adult['sex'],columns=df_adult['income']).apply(lambda x:(x/x.sum()*100),axis=1)
it
# Out:
# income      <=50K       >50K
# sex
# Female  89.053941  10.946059
# Male    69.426342  30.573658

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.pivot_table(df_adult,index=['race'],columns=['income'],values='age',aggfunc='mean')
# Out:
# income                  <=50K       >50K
# race
# Amer-Indian-Eskimo  36.843636  39.694444
# Asian-Pac-Islander  36.073394  42.373188
# Black               36.927293  43.713178
# Other               32.646341  41.440000
# White               36.839316  44.384713

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.pivot_table(df_adult,index=['occupation'],columns=['sex'],values='age',aggfunc='mean')
# Out:
# sex                   Female       Male
# occupation
# ?                  36.542212  44.525948
# Adm-clerical       36.852188  37.195458
# Armed-Forces             NaN  30.222222
# Craft-repair       39.004505  39.033015
# Exec-managerial    39.485764  43.239078
# Farming-fishing    41.092308  41.219591
# Handlers-cleaners  34.554878  31.840796
# Machine-op-inspct  38.121818  37.561295
# Other-service      35.683889  34.065552
# Priv-house-serv    42.255319  32.375000
# Prof-specialty     38.858086  41.475429
# Protective-serv    34.868421  39.495637
# Sales              33.060174  39.625890
# Tech-support       34.718391  38.405172
# Transport-moving   38.888889  40.276045

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.pivot_table(df_adult,index=['workclass'],columns=['income'],values='age',aggfunc='mean')
# Out:
# income                <=50K       >50K
# workclass
# ?                 39.258359  55.617801
# Federal-gov       40.624788  45.711590
# Local-gov         40.704607  44.254457
# Never-worked      20.571429        NaN
# Private           35.113404  42.815233
# Self-emp-inc      43.206478  48.249196
# Self-emp-not-inc  44.388553  46.428177
# State-gov         37.279365  45.209632
# Without-pay       47.785714        NaN

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(index=df_adult['income'],columns=df_adult['marital.status'])
# Out:
# marital.status  Divorced  Married-AF-spouse  Married-civ-spouse  \
# income
# <=50K               3980                 13                8284
# >50K                 463                 10                6692
#
# marital.status  Married-spouse-absent  Never-married  Separated  Widowed
# income
# <=50K                             384          10192        959      908
# >50K                               34            491         66       85

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.pivot_table(df_adult,index=['occupation'],columns=['income'],values='age',aggfunc='mean')
# Out:
# income                 <=50K       >50K
# occupation
# ?                  39.179177  55.617801
# Adm-clerical       35.987128  43.254438
# Armed-Forces       28.250000  46.000000
# Craft-repair       37.659621  43.712594
# Exec-managerial    39.609152  44.898374
# Farming-fishing    40.445961  47.060870
# Handlers-cleaners  31.462617  42.662791
# Machine-op-inspct  37.048516  42.388000
# Other-service      34.664661  41.518248
# Priv-house-serv    41.689189  47.000000
# Prof-specialty     37.942569  43.677246
# Protective-serv    37.705479  41.545024
# Sales              34.780277  44.336724
# Tech-support       34.355039  43.102473
# Transport-moving   39.120595  44.496875
